# %% [markdown]
# # Colab

# %%
from google.colab import drive     # Conectar a Google drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # CAMBIAR A R

# %%
install.packages("remotes")
library(remotes)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("raster")
library("raster") #demora 11 minutos
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sp’, ‘terra’
#
#
# Loading required package: sp

# %%
library(devtools)
# Out:
# Loading required package: usethis
#
#
# Attaching package: ‘devtools’
#
#
# The following objects are masked from ‘package:remotes’:
#
#     dev_package_deps, github_pull, github_release, install_bioc,
#     install_bitbucket, install_cran, install_deps, install_dev,
#     install_git, install_github, install_gitlab, install_local,
#     install_svn, install_url, install_version, update_packages

# %%
devtools::install_github(c( "SantanderMetGroup/climate4R.UDG",
                 "SantanderMetGroup/transformeR",
                 "SantanderMetGroup/visualizeR",
                 "SantanderMetGroup/downscaleR")) #demora 15 minutos
# Out:
# Warning message:
# “`install_github()` was deprecated in devtools 2.5.0.
# ℹ Please use pak::pak("user/repo") instead.”
# Downloading GitHub repo SantanderMetGroup/climate4R.UDG@HEAD
# bitops (NA -> 1.0-9    ) [CRAN]
# rJava  (NA -> 1.0-18   ) [CRAN]
# RCurl  (NA -> 1.98-1.18) [CRAN]
# Installing 3 packages: bitops, rJava, RCurl
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in i.p(...):
# “installation of package ‘rJava’ had non-zero exit status”
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpUnplpL/remotes35e171cf353d/SantanderMetGroup-climate4R.UDG-2fffeb5/DESCRIPTION’ ... OK
# * preparing ‘climate4R.UDG’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘climate4R.UDG_0.2.6.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in i.p(...):
# “installation of package ‘/tmp/RtmpUnplpL/file35e142d7a8e8/climate4R.UDG_0.2.6.tar.gz’ had non-zero exit status”
# Downloading GitHub repo SantanderMetGroup/transformeR@HEAD
# Rcpp      (1.1.1 -> 1.1.1-1.1) [CRAN]
# dotCall64 (NA    -> 1.2      ) [CRAN]
# maps      (NA    -> 3.4.3    ) [CRAN]
# spam      (NA    -> 2.11-3   ) [CRAN]
# kohonen   (NA    -> 3.0.13   ) [CRAN]
# RcppEigen (NA    -> 0.3.4.0.2) [CRAN]
# magrittr  (2.0.4 -> 2.0.5    ) [CRAN]
# fields    (NA    -> 17.3     ) [CRAN]
# akima     (NA    -> 0.6-3.6  ) [CRAN]
# abind     (NA    -> 1.4-8    ) [CRAN]
# Installing 10 packages: Rcpp, dotCall64, maps, spam, kohonen, RcppEigen, magrittr, fields, akima, abind
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpUnplpL/remotes35e16915bb0a/SantanderMetGroup-transformeR-4b58e04/DESCRIPTION’ ... OK
# * preparing ‘transformeR’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘transformeR_2.2.5.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Downloading GitHub repo SantanderMetGroup/visualizeR@HEAD
# cpp11        (0.5.3    -> 0.5.5   ) [CRAN]
# vctrs        (0.7.2    -> 0.7.3   ) [CRAN]
# rlang        (1.1.7    -> 1.2.0   ) [CRAN]
# glue         (1.8.0    -> 1.8.1   ) [CRAN]
# cli          (3.6.5    -> 3.6.6   ) [CRAN]
# deldir       (NA       -> 2.0-4   ) [CRAN]
# proxy        (NA       -> 0.4-29  ) [CRAN]
# RcppArmad... (NA       -> 15.2.6-1) [CRAN]
# dplyr        (1.2.0    -> 1.2.1   ) [CRAN]
# interp       (NA       -> 1.1-6   ) [CRAN]
# jpeg         (NA       -> 0.1-11  ) [CRAN]
# png          (NA       -> 0.1-9   ) [CRAN]
# dtw          (NA       -> 1.23-2  ) [CRAN]
# CircStats    (NA       -> 0.2-7   ) [CRAN]
# pbapply      (NA       -> 1.7-4   ) [CRAN]
# SpecsVeri... (NA       -> 0.5-3   ) [CRAN]
# zoo          (NA       -> 1.8-15  ) [CRAN]
# sm           (NA       -> 2.2-6.0 ) [CRAN]
# data.table   (1.18.2.1 -> 1.18.4  ) [CRAN]
# padr         (NA       -> 0.6.3   ) [CRAN]
# latticeExtra (NA       -> 0.6-31  ) [CRAN]
# verification (NA       -> 1.45    ) [CRAN]
# easyVerif... (NA       -> 0.4.5   ) [CRAN]
# vioplot      (NA       -> 0.5.1   ) [CRAN]
# mapplots     (NA       -> 1.5.3   ) [CRAN]
# Installing 25 packages: cpp11, vctrs, rlang, glue, cli, deldir, proxy, RcppArmadillo, dplyr, interp, jpeg, png, dtw, CircStats, pbapply, SpecsVerification, zoo, sm, data.table, padr, latticeExtra, verification, easyVerification, vioplot, mapplots
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpUnplpL/remotes35e1e815b3e/SantanderMetGroup-visualizeR-3fec84d/DESCRIPTION’ ... OK
# * preparing ‘visualizeR’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘visualizeR_1.6.4.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Downloading GitHub repo SantanderMetGroup/downscaleR@HEAD
# iterators  (NA -> 1.0.14 ) [CRAN]
# shape      (NA -> 1.4.6.1) [CRAN]
# foreach    (NA -> 1.5.2  ) [CRAN]
# here       (NA -> 1.0.2  ) [CRAN]
# RcppTOML   (NA -> 0.2.3  ) [CRAN]
# sticky     (NA -> 0.5.6.1) [CRAN]
# evd        (NA -> 2.3-7.1) [CRAN]
# glmnet     (NA -> 5.0    ) [CRAN]
# deepnet    (NA -> 0.2.1  ) [CRAN]
# reticulate (NA -> 1.46.0 ) [CRAN]
# Installing 10 packages: iterators, shape, foreach, here, RcppTOML, sticky, evd, glmnet, deepnet, reticulate
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpUnplpL/remotes35e1445f509/SantanderMetGroup-downscaleR-6e8f200/DESCRIPTION’ ... OK
# * preparing ‘downscaleR’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘downscaleR_3.3.4.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(devtools)
library(transformeR)
library(visualizeR)
library(downscaleR)
library(raster)
# Out:
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.2.5 (2026-01-21) is loaded
#
# Please see 'citation("transformeR")' to cite this package.
#
# visualizeR version 1.6.4 (2023-10-26) is loaded
#
# Please see 'citation("visualizeR")' to cite this package.
#
# downscaleR version 3.3.4 (2023-06-22) is loaded
#
# Please use 'citation("downscaleR")' to cite this package.

# %%
install.packages("fields")
install.packages("plotrix")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(fields)
library(plotrix)
library(readxl)
# Out:
# Loading required package: spam
#
# Spam version 2.11-3 (2026-01-05) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
#
# Attaching package: ‘spam’
#
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
#
# Loading required package: viridisLite
#
# Loading required package: RColorBrewer
#
#
# Try help(fields) to get started.
#
#
# Attaching package: ‘fields’
#
#
# The following object is masked from ‘package:visualizeR’:
#
#     bubblePlot
#
#
# The following object is masked from ‘package:transformeR’:
#
#     fillGrid
#
#
#
# Attaching package: ‘plotrix’
#
#
# The following object is masked from ‘package:fields’:
#
#     color.scale

# %% [markdown]
# # Downscalling

# %%
#IMPORTANTE AQUI COLOCAR TU PROPIA CARPETA DONDE ESAN TUS ARCHIVOS
ruta_carpeta <- "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6/"

# %%
archivos <- list.files(path = ruta_carpeta, pattern = "\\.csv$", full.names = TRUE)
print(archivos) #si no te sale nada, preocupate, significa que tu carpeta esta mal
# Out:
#  [1] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000830.csv"
#  [2] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000833.csv"
#  [3] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000837.csv"
#  [4] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000840.csv"
#  [5] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000846.csv"
#  [6] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_BCC-CSM2-MR_ho00000830.csv"
#  [7] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_BCC-CSM2-MR_ho00000833.csv"
#  [8] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_BCC-CSM2-MR_ho00000837.csv"
#  [9] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_BCC-CSM2-MR_ho00000840.csv"
# [10] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_BCC-CSM2-MR_ho00000846.csv"
# [11] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_KACE-1-0-G_ho00000830.csv"
# [12] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_KACE-1-0-G_ho00000833.csv"
# [13] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_KACE-1-0-G_ho00000837.csv"
# [14] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_KACE-1-0-G_ho00000840.csv"
# [15] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_KACE-1-0-G_ho00000846.csv"
# [16] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_NorESM2-MM_ho00000830.csv"
# [17] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_NorESM2-MM_ho00000833.csv"
# [18] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_NorESM2-MM_ho00000837.csv"
# [19] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_NorESM2-MM_ho00000840.csv"
# [20] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_NorESM2-MM_ho00000846.csv"

# %% [markdown]
# Aqui como son 2, se van a dividir con sus compañeros que estacion van a hacer el downscalling

# %%
estacion_numero <- 1
archivos[estacion_numero]
# Out:
# [1] "/content/drive/MyDrive/4Students_2026/Data/Selva/Resultados_CMIP6//comparacion_ACCESS-CM2_ho00000830.csv"

# %%
# Tu variable actual
nombre_con_extension <- basename(archivos[estacion_numero])
# Reemplazamos "comparacion" por nada ""
nombre_corto <- gsub("comparacion_", "", nombre_con_extension)
print(nombre_corto)
# Out:
# [1] "ACCESS-CM2_ho00000830.csv"

# %%
ruta_exportar <- "/content/drive/MyDrive/4Students_2026/Data/Selva/Downscalling/"  #pongan el / al final

# %% [markdown]
# ## Datos historicos

# %%
df <- read.table(
  file = archivos[estacion_numero],
  sep = ",",
  header = TRUE
)
df$Fecha <- as.Date(df$Fecha)
df
# Out:
#       Fecha      PR_ssp245    PR_ssp585    TMAX_ssp245 TMAX_ssp585 TMIN_ssp245
# 49662 24.36319    NA       NA       NA
# 49663 25.04068    NA       NA       NA
# 49664 24.03116    NA       NA       NA
# 49665 23.87491    NA       NA       NA
# 49666 23.59976    NA       NA       NA
# 49667 24.03433    NA       NA       NA
# 49668 24.02628    NA       NA       NA
# 49669 23.88980    NA       NA       NA
# 49670 23.93253    NA       NA       NA
# 49671 23.98965    NA       NA       NA
# 49672 23.97671    NA       NA       NA
# 49673 23.64078    NA       NA       NA

# %%
date_cal<-seq(as.Date("1981-01-01"),as.Date("2000-12-31"),by="day")
date_val<-seq(as.Date("2001-01-01"),as.Date("2014-12-31"),by="day")

# %%
o1 <-list();p1 <-list();s1 <-list();
o1[[1]]<-df$Tmin_obs[df$Fecha %in% date_cal] #DATA OBSERVADA - CALIBRACION
p1[[1]]<-df$TMIN_ssp245[df$Fecha %in% date_cal] #DATA HISTORICA DEL MODELO - CALIBRACION (1981-2000)
s1[[1]]<-df$TMIN_ssp245[df$Fecha %in% date_val] #validacion (2000-2014)

# %%
plot(date_val,df$Tmin_obs[df$Fecha %in% date_val],col="black",type="l",lty=1,xlab="Fechas",ylab="Temp")
# Out:
# plot without title

# %%
data_bc1<-list()
data_bc1[[1]]<-as.vector(downscaleR:::biasCorrection1D(o=o1,p=p1,s=s1,
                                                      method="eqm",
                                                      pr.threshold=0.1,
                                                      n.quantiles = NULL,
                                                      extrapolation = "constant",
                                                      precip=FALSE))

plot(date_val,s1[[1]],type="l",lty=1,col="blue",xlab="Fechas",ylab="Temp") #datos

lines(date_val,df$Tmin_obs[df$Fecha %in% date_val],col="black") #Data historica - validacion
lines(date_val,data_bc1[[1]],col="red")
legend(date_val[1], 20, legend=c("Raw", "Obs","Corrected"),col=c("blue","black", "red"), lty=1:2, cex=0.8)
# Out:
# plot without title

# %%
data_bc1[[2]]<-as.vector(downscaleR:::biasCorrection1D(o=o1,p=p1,s=s1,
                                                        method="scaling",
                                                        scaling.type="multiplicative",
                                                        extrapolation = "constant",
                                                        precip=FALSE))


#QUANTILE DATA MAPPING
data_bc1[[3]]<-as.vector(downscaleR:::biasCorrection1D(o=o1,p=p1,s=s1,
                                                        method="qdm",
                                                        pr.threshold=0.1,
                                                        n.quantiles = NULL,
                                                        extrapolation = "constant",
                                                        precip=FALSE))

# %%
obs1 <-df$Tmin_obs[df$Fecha %in% date_val]
df_taylor_val1<-data.frame(date=date_val,obs=obs1, eqm=data_bc1[[1]],
                          scaling = data_bc1[[2]], qdm= data_bc1[[3]])
df_taylor_val1
# Out:
#      date       obs    eqm      scaling  qdm
# 1    2001-01-01 19.585 17.35644 17.32947 17.34626
# 2    2001-01-02 19.250 17.55500 17.49498 17.54172
# 3    2001-01-03 19.485 17.96534 17.87264 17.92725
# 4    2001-01-04 18.925 17.40000 17.36815 17.39154
# 5    2001-01-05 18.755 17.57000 17.51115 17.56001
# 6    2001-01-06 19.485 18.12164 18.02173 18.09733
# 7    2001-01-07 18.770 15.11000 15.53212 15.11883
# 8    2001-01-08 19.015 17.96687 17.87334 17.92844
# 9    2001-01-09 19.080 18.09038 17.99407 18.07248
# 5111 2014-12-29 17.345 16.71694 16.74926 16.60985
# 5112 2014-12-30 18.030 16.07137 16.24079 15.90213
# 5113 2014-12-31 18.020 16.93000 16.92508 16.82984

# %%
write.table(df_taylor_val1,paste0(ruta_exportar,"Downscalling_hist_tmin_",nombre_corto), sep = ",", row.names = FALSE) #guardo las metricas

# %% [markdown]
# ## Datos futuros ssp 2 - 4.5

# %%
date_calF<-seq(as.Date("1981-01-01"),as.Date("2014-12-31"),by="day")
date_ssp <-seq(as.Date("1981-01-01"),as.Date("2100-12-31"),by="day")

# %%
o2<-list();p2<-list();s2<-list();
o2[[1]]<-df$Tmin_obs[df$Fecha %in% date_calF] #Data historica 1981-2014
p2[[1]]<-df$TMIN_ssp245[df$Fecha %in% date_calF] #Data historica del modelo 1981-2014
s2[[1]]<-df$TMIN_ssp245[df$Fecha %in% date_ssp]  #Data futura 2015-2100

data_bc2 <-list()
data_bc2[[1]]<-as.vector(downscaleR:::biasCorrection1D(o=o2,p=p2,s=s2,
                                                        method="eqm",
                                                        pr.threshold=0.1,
                                                        n.quantiles = NULL,
                                                        extrapolation = "constant",
                                                        precip=FALSE))

data_bc2[[2]]<-as.vector(downscaleR:::biasCorrection1D(o=o2,p=p2,s=s2,
                                                        method="scaling",
                                                        scaling.type="multiplicative",
                                                        extrapolation = "constant",
                                                        precip=FALSE))


#QUANTILE DATA MAPPING
data_bc2[[3]]<-as.vector(downscaleR:::biasCorrection1D(o=o2,p=p2,s=s2,
                                                        method="qdm",
                                                        pr.threshold=0.1,
                                                        n.quantiles = NULL,
                                                        extrapolation = "constant",
                                                        precip=FALSE))

# %%
plot(df$Fecha[df$Fecha %in% date_ssp],df$TMIN_ssp245[df$Fecha %in% date_ssp] ,col="black")
# Out:
# plot without title

# %%
# 1. Creamos el primer gráfico (el lienzo)
plot(df$Fecha[df$Fecha %in% date_ssp],df$TMIN_ssp245[df$Fecha %in% date_ssp], type = "l",
      lty = 2, col = "black")

# 2. Agregamos la segunda serie sobre el mismo gráfico (sin borrar)
lines(df$Fecha[df$Fecha %in% date_ssp], data_bc2[[3]],
     type = "l", lty = 1, col = "red",
     ylim = c(0, 100),
     main = "Comparación de Temperatura",
     xlab = "Fecha", ylab = "Temp (°C)")

# 3. Agregamos la leyenda
legend("topleft", # Puedes usar coordenadas o palabras clave como "topleft"
       legend = c("Modelo downscalling", "Modelo original"),
       col = c("red", "black"),
       lty = 1:2,
       cex = 0.8,
       bty = "n") # bty="n" quita el recuadro de la leyenda si prefieres
# Out:
# plot without title

# %%
df_taylor_futuro1<-data.frame(date=df$Fecha[df$Fecha %in% date_ssp],eqm=data_bc2[[1]],
                          scaling = data_bc2[[2]], qdm= data_bc2[[3]])
df_taylor_futuro1
# Out:
#       date       eqm      scaling  qdm
# 1     1981-01-01 16.47000 16.52560 16.15075
# 2     1981-01-02 16.05554 16.20720 15.84781
# 3     1981-01-03 15.73560 15.97224 15.62800
# 4     1981-01-04 15.88500 16.08594 15.73353
# 5     1981-01-05 16.86000 16.81856 16.48165
[1]]<-df$TMIN_ssp245[df$Fecha %in% date_calF] #Data historica del modelo 1981-2014
s3[[1]]<-df$TMIN_ssp245[df$Fecha %in% date_ssp]  #Data futura 2015-2100

data_bc3 <-list()
data_bc3[[1]]<-as.vector(downscaleR:::biasCorrection1D(o=o3,p=p3,s=s3,
                                                        method="eqm",
                                                        pr.threshold=0.1,
                                                        n.quantiles = NULL,
                                                        extrapolation = "constant",
                                                        precip=FALSE))

data_bc3[[2]]<-as.vector(downscaleR:::biasCorrection1D(o=o3,p=p3,s=s3,
                                                        method="scaling",
                                                        scaling.type="multiplicative",
                                                        extrapolation = "constant",
                                                        precip=FALSE))


#QUANTILE DATA MAPPING
data_bc3[[3]]<-as.vector(downscaleR:::biasCorrection1D(o=o3,p=p3,s=s3,
                                                        method="qdm",
                                                        pr.threshold=0.1,
                                                        n.quantiles = NULL,
                                                        extrapolation = "constant",
                                                        precip=FALSE))

# %%
plot(df$Fecha[df$Fecha %in% date_ssp],df$TMIN_ssp585[df$Fecha %in% date_ssp] ,col="black")
# Out:
# plot without title

# %%
# 1. Creamos el primer gráfico (el lienzo)
plot(df$Fecha[df$Fecha %in% date_ssp],df$TMIN_ssp585[df$Fecha %in% date_ssp], type = "l",
      lty = 2, col = "black")

# 2. Agregamos la segunda serie sobre el mismo gráfico (sin borrar)
lines(df$Fecha[df$Fecha %in% date_ssp], data_bc3[[3]],
     type = "l", lty = 1, col = "red",
     ylim = c(0, 100),
     main = "Comparación de Temperatura",
     xlab = "Fecha", ylab = "Temperatura (°C)")

# 3. Agregamos la leyenda
legend("topleft", # Puedes usar coordenadas o palabras clave como "topleft"
       legend = c("Modelo downscalling", "Modelo original"),
       col = c("red", "black"),
       lty = 1:2,
       cex = 0.8,
       bty = "n") # bty="n" quita el recuadro de la leyenda si prefieres
# Out:
# plot without title

# %%
df_taylor_futuro2<-data.frame(date=df$Fecha[df$Fecha %in% date_ssp],eqm=data_bc3[[1]],
                          scaling = data_bc3[[2]], qdm= data_bc3[[3]])
df_taylor_futuro2
# Out:
#       date       eqm      scaling  qdm
# 1     1981-01-01 16.47000 16.52560 16.15072
# 2     1981-01-02 16.05554 16.20720 15.84782
# 3     1981-01-03 15.73560 15.97224 15.62797
# 4     1981-01-04 15.88500 16.08594 15.73352
# 5     1981-01-05 16.86000 16.81856 16.48167
# 6     1981-01-06 17.21000 17.10853 16.84205
# 7     1981-01-07 16.54000 16.56182 16.18834
# 8     1981-01-08 15.93000 16.10886 15.75788
# 9     1981-01-09 17.18500 17.07530 16.79599
# 10    1981-01-10 16.03000 16.18955 15.82764
# 11    1981-01-11 15.48500 15.79848 15.44780
# 12    1981-01-12 16.18500 16.29614 15.92793
# 13    1981-01-13 16.53500 16.55563 16.17616
# 14    1981-01-14 16.90728 16.85844 16.52182
# 15    1981-01-15 16.66000 16.66268 16.29887
# 16    1981-01-16 16.55000 16.56961 16.19319
# 17    1981-01-17 16.74606 16.71586 16.36391
# 18    1981-01-18 16.60000 16.61110 16.24257
# 19    1981-01-19 15.94000 16.11436 15.75998
# 20    1981-01-20 17.24000 17.13421 16.86678
# 21    1981-01-21 17.01500 16.94670 16.62754
# 22    1981-01-22 17.14500 17.03839 16.75626
# 23    1981-01-23 17.08173 16.99873 16.69854
# 24    1981-01-24 15.72124 15.96124 15.61260
# 25    1981-01-25 17.63500 17.48975 17.30712
# 26    1981-01-26 17.22000 17.11564 16.85299
# 27    1981-01-27 16.37500 16.44675 16.06529
# 28    1981-01-28 16.33376 16.41442 16.03237
# 29    1981-01-29 16.45358 16.50933 16.13409
# 30    1981-01-30 15.82000 16.03528 15.68880
# ⋮     ⋮          ⋮        ⋮        ⋮
# 43800 2100-12-02 22.81771 20.08211 20.64991
# 43801 2100-12-03 24.18157 21.23789 22.61410
# 43802 2100-12-04 24.03697 21.09738 22.32914
# 43803 2100-12-05 24.03615 21.09531 22.32674
# 43804 2100-12-06 23.58817 20.76591 21.72601
# 43805 2100-12-07 24.09246 21.15422 22.43578
# 43806 2100-12-08 23.85963 20.98070 22.10686
# 43807 2100-12-09 23.77698 20.83170 21.85110
# 43808 2100-12-10 22.90049 20.10572 20.67759
# 43809 2100-12-11 20.86003 19.47396 19.82826
# 43810 2100-12-12 23.34849 20.54493 21.36221
# 43811 2100-12-13 24.13714 21.19617 22.50729
# 43812 2100-12-14 23.97355 21.02356 22.20210
# 43813 2100-12-15 23.55898 20.67949 21.55508
# 43814 2100-12-16 23.34989 20.55341 21.37548
# 43815 2100-12-17 18.08500 17.86545 17.83241
# 43816 2100-12-18 17.30000 17.18441 16.94707
# 43817 2100-12-19 18.31500 18.02041 18.04490
# 43818 2100-12-20 17.96539 17.76826 17.70585
# 43819 2100-12-21 17.89000 17.69422 17.59754
# 43820 2100-12-22 20.06204 19.11980 19.39837
# 43821 2100-12-23 18.31500 18.02018 18.04498
# 43822 2100-12-24 20.32500 19.24794 19.53923
# 43823 2100-12-25 20.20535 19.19843 19.48940
# 43824 2100-12-26 16.30500 16.39952 16.01841
# 43825 2100-12-27 22.83826 20.09312 20.66529
# 43826 2100-12-28 22.60637 20.01082 20.55540
# 43827 2100-12-29 23.24815 20.42137 21.14612
# 43828 2100-12-30 22.68094 20.03787 20.58771
# 43829 2100-12-31 22.94683 20.13713 20.70978

# %%
write.table(df_taylor_futuro2,paste0(ruta_exportar,"Downscalling_ssp5_8.5_tmin_",nombre_corto), sep = ",", row.names = FALSE) #guardo las metricas

# %% [markdown]
# # IMPORTANTE
# Corre el siguiente codigo y solo vuelve a correr (NO INSTALES LIBRERIAS), te vas el df nomas

# %%
rm(list=ls()) #para limpiar el entorno
